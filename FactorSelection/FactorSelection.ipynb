# %%
import pandas as pd
from datetime import date
import sys
import numpy as np

# %%
dfX_hist = pd.read_excel("./dfX_hist.xlsx")

# %%
dfX_hist.loc[:,("pos_call_finish","official_finish_position")].head()
# Out:
#    pos_call_finish  official_finish_position
# 0              5.0                       5.0
# 1              3.0                       3.0
# 2              6.0                       6.0
# 3              1.0                       1.0
# 4              2.0                       2.0

# %%
dfX_hist.loc[:,("final_tote_odds","official_finish_position")].head()
# Out:
#    final_tote_odds  official_finish_position
# 0              5.5                       5.0
# 1              8.5                       3.0
# 2             27.0                       6.0
# 3              1.4                       1.0
# 4              1.6                       2.0

# %%
dfX_hist['x8is_favorate_odds'] = dfX_hist.groupby('race_id')['final_tote_odds'].transform(lambda x: x==x.min())

# %%
dfX_hist['x8is_favorate_win'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]==1, axis=1)

# %%
dfX_hist['x8is_favorate_place'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]==2, axis=1)

# %%
dfX_hist['x8is_favorate_show'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]==3, axis=1)

# %%
dfX_hist['x8is_favorate_otb'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]>3, axis=1)

# %%
last_5_positions = ["finish_pos_{}".format(i) for i in range(5)]
last_10_positions = ["finish_pos_{}".format(i) for i in range(10)]
dfX_hist["x8is_winless_in_5"] = dfX_hist.loc[:,last_5_positions].apply(lambda x: np.sum(x==1), axis=1)
dfX_hist["x8is_winless_in_10"] = dfX_hist.loc[:,last_10_positions].apply(lambda x: np.sum(x==1), axis=1)

# %%
dfX_hist.to_csv("dfX_hist_new.csv")

# %%
dfX_hist_new = pd.read_csv("dfX_hist_new.csv")

# %%
dfX_hist_new.loc[:,["x8is_favorate_otb","x8is_winless_in_10"]+last_10_positions].head(20)
# Out:
#     x8is_favorate_otb  x8is_winless_in_10  finish_pos_0  finish_pos_1  \
# 0               False                   0             4             3
# 1               False                   0            10             5
# 2               False                   0             7             5
# 3               False                   0             6             3
# 4               False                   0             2             2
# 5               False                   0             6             6
# 6               False                   0             3             9
# 7               False                   1             6             1
# 8               False                   1             1             7
# 9                True                   1             5             5
# 10              False                   0             4             7
# 11              False                   7             7             7
# 12              False                   1             2             8
# 13              False                   1             1             2
# 14              False                   2             3             4
# 15              False                   0             2             4
# 16              False                   2             5             9
# 17              False                   2             2             5
# 18               True                  10             1             1
# 19              False                   2             3             2
#
#     finish_pos_2  finish_pos_3  finish_pos_4  finish_pos_5  finish_pos_6  \
# 0              6             7             8             7             3
# 1              8             8             8             8             8
# 2              7             5             4             8             6
# 3              3             3             3             3             3
# 4              9             8             4             4             7
# 5              6             6             6             6             6
# 6              8             6             5             8             6
# 7              3            10             9             9             9
# 8             11             2             2             8             8
# 9              7             1             7             2             2
# 10             4             8             3             5             2
# 11             5             1             1             1             1
# 12             4             3             2             9             5
# 13             2             4             4             4             4
# 14             1             6             6             5             4
# 15             2             7             9             5             4
# 16             6             3             1             3             2
# 17             7             1             2             4             1
# 18             1             1             1             1             1
# 19            10             2             1             2             6
#
#     finish_pos_7  finish_pos_8  finish_pos_9
# 0              6             6             6
# 1              8             8             8
# 2              9             6             9
# 3              3             3             3
# 4              7             7             7
# 5              6             6             6
# 6              6             6             6
# 7              9             9             9
# 8              8             8             8
# 9              7             5             5
# 10             6             5             4
# 11             1             1             1
# 12             1             2             3
# 13             4             4             4
# 14             1             8             8
# 15             8             5             2
# 16             1             6             7
# 17             2             9             9
# 18             1             1             1
# 19             2             1             8
