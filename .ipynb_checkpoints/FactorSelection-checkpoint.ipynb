# %%
import pandas as pd
from datetime import date
import sys

# %%
import os
from os import path

# %%
os.getcwd()
# Out:
# '/Users/xiayuxuan/Codes/EquineTrading'

# %%
dfX_hist = pd.read_excel("./dfX_hist.xlsx")

# %%
dfX_hist.loc[:,("pos_call_finish","official_finish_position")].head()
# Out:
#    pos_call_finish  official_finish_position
# 0              5.0                       5.0
# 1              3.0                       3.0
# 2              6.0                       6.0
# 3              1.0                       1.0
# 4              2.0                       2.0

# %%
# Out:
# array(['2fHDWPaceParforLevel', '4fHDWPaceParforLevel',
#        '6fHDWPaceParforLevel', 'AlternateSpeedPoints',
#        'BestHDWSpeedAllWeatherSurface', 'HDWPSRRating',
#        'HDWSLatePaceParForLevel', 'HDWSpeedParForClassLevel',
#        'HDWSpeedRating_0', 'HDWSpeedRating_1', 'HDWSpeedRating_2',
#        'HDWSpeedRating_3', 'HDWSpeedRating_4', 'HDWSpeedRating_5',
#        'HDWSpeedRating_6', 'HDWSpeedRating_7', 'HDWSpeedRating_8',
#        'HDWSpeedRating_9', 'NumericHDWRunStyleDesignation', 'SpeedPoints',
#        'ae_indicator', 'age_limit', 'age_restriction',
#        'apprentice_weight_allowance', 'apprentice_weight_alw',
#        'approx_dist', 'bestCramerSpeedFigDirt', 'bet_description',
#        'breed_type', 'call_1_lengths_behind', 'call_2_lengths_behind',
#        'call_3_lengths_behind', 'call_4_lengths_behind', 'claimed',
#        'claiming_price', 'claiming_price_0', 'claiming_price_1',
#        'claiming_price_2', 'claiming_price_3', 'claiming_price_4',
#        'claiming_price_5', 'claiming_price_6', 'claiming_price_7',
#        'claiming_price_8', 'claiming_price_9', 'coupled_entry', 'date',
#        'date_0', 'date_1', 'date_2', 'date_3', 'date_4', 'date_5',
#        'date_6', 'date_7', 'date_8', 'date_9', 'days_since_last_race',
#        'distance', 'earnings_0', 'earnings_1', 'earnings_2', 'earnings_3',
#        'earnings_4', 'earnings_5', 'earnings_6', 'earnings_7',
#        'earnings_8', 'earnings_9', 'entropy_morning_line',
#        'final_tote_odds', 'finish_lengths_behind', 'finish_pos_0',
#        'finish_pos_1', 'finish_pos_2', 'finish_pos_3', 'finish_pos_4',
#        'finish_pos_5', 'finish_pos_6', 'finish_pos_7', 'finish_pos_8',
#        'finish_pos_9', 'full_race_conditions', 'gelded_since_last_start',
#        'horse_claiming_price', 'index', 'jcp_track_sym_pp', 'jockey',
#        'jockey_first_name', 'jockey_last_name', 'jockey_middle_name',
#        'jockey_name', 'low_claiming_price', 'main_track_only', 'month',
#        'morning_line', 'name_result', 'name_runner', 'nonbetting',
#        'odds_0', 'odds_1', 'odds_2', 'odds_3', 'odds_4', 'odds_5',
#        'odds_6', 'odds_7', 'odds_8', 'odds_9', 'official_finish_position',
#        'pct_of_purse_earnings', 'pos_call_1', 'pos_call_2', 'pos_call_3',
#        'pos_call_4', 'pos_call_finish', 'pos_call_start',
#        'pos_call_stretch', 'post_position', 'pp_num',
#        'prob_x8runner_HDWPSRRating_norm_par', 'probs_morning_line',
#        'program_number', 'program_pos', 'program_post_pos', 'purse',
#        'purse_0', 'purse_1', 'purse_2', 'purse_3', 'purse_4', 'purse_5',
#        'purse_6', 'purse_7', 'purse_8', 'purse_9', 'race_classification',
#        'race_classification_0', 'race_classification_1',
#        'race_classification_2', 'race_classification_3',
#        'race_classification_4', 'race_classification_5',
#        'race_classification_6', 'race_classification_7',
#        'race_classification_8', 'race_classification_9',
#        'race_conditions', 'race_id', 'race_id_pp', 'race_id_result',
#        'race_id_runner', 'race_number', 'race_race_num_pp', 'race_type',
#        'rank_final_tote_odds', 'rank_morning_line', 'rank_odds',
#        'riderROI', 'runner_id', 'runner_id_result',
#        'runner_program_number_pp', 'scratch_code', 'scratched_result',
#        'scratched_runner', 'sex_restriction', 'state_bred_flag',
#        'stretch_call_lengths_behind', 'surface', 'track_id',
#        'track_record', 'trainer', 'trainerROI', 'trainer_first_name',
#        'trainer_last_name', 'trainer_middle_name', 'trainer_name',
#        'weekday', 'weight', 'wknum_0', 'wknum_1', 'wknum_2', 'wknum_3',
#        'wknum_4', 'wknum_5', 'wknum_6', 'wknum_7', 'wknum_8', 'wknum_9',
#        'x8_diff_odds_0', 'x8_diff_odds_1', 'x8_diff_odds_2',
#        'x8_diff_odds_3', 'x8_diff_odds_4', 'x8_diff_odds_5',
#        'x8_diff_odds_6', 'x8_diff_odds_7', 'x8_diff_odds_8',
#        'x8_diff_odds_9', 'x8_num_runners', 'x8_num_starters_pp',
#        'x8_outperform', 'x8_pct_dirty_HDWPSRRating_par_norm',
#        'x8_pctofpurse_0', 'x8_pctofpurse_1', 'x8_pctofpurse_2',
#        'x8_pctofpurse_3', 'x8_pctofpurse_4', 'x8_pctofpurse_5',
#        'x8_pctofpurse_6', 'x8_pctofpurse_7', 'x8_pctofpurse_8',
#        'x8_pctofpurse_9', 'x8_prob_odds_0', 'x8_prob_odds_1',
#        'x8_prob_odds_2', 'x8_prob_odds_3', 'x8_prob_odds_4',
#        'x8_prob_odds_5', 'x8_prob_odds_6', 'x8_prob_odds_7',
#        'x8_prob_odds_8', 'x8_prob_odds_9', 'x8_probs_odds_norm_win_final',
#        'x8is_HDWPSRRating_norm_par', 'x8is_apprentice_weight_alw',
#        'x8is_close_route', 'x8is_close_sprint', 'x8is_exacta',
#        'x8is_exacta_longshot', 'x8is_favorite_odds',
#        'x8is_firsttimestarter', 'x8is_longshot', 'x8is_odds_on_final',
#        'x8is_otb', 'x8is_rank_1_HDWPSRating', 'x8is_secondtimestarter',
#        'x8is_superfecta', 'x8is_superfecta_longshot', 'x8is_trifecta',
#        'x8is_trifecta_lonsghot', 'x8is_win', 'x8is_win_longshot',
#        'x8name_result', 'x8name_runner', 'x8rank_speed_2of3',
#        'x8ratio_earnings_0_claim', 'x8ratio_purse_0_claim',
#        'x8runner_HDWPSRRating_norm_par',
#        'x8runner_rank_HDWPSRRating_norm_par', 'x8speed_2of3',
#        'x8speed_norm_2of3_par', 'year'], dtype=object)

# %%
dfX_hist.loc[:,("final_tote_odds","official_finish_position")]
# Out:
#       final_tote_odds  official_finish_position
# 0                 5.5                       5.0
# 1                 8.5                       3.0
# 2                27.0                       6.0
# 3                 1.4                       1.0
# 4                 1.6                       2.0
# 5                21.4                       4.0
# 6                13.1                       7.0
# 7                 3.2                       2.0
# 8                15.8                       3.0
# 9                 1.9                       6.0
# 10               13.5                       5.0
# 11                3.0                       1.0
# 12                2.9                       4.0
# 13                5.1                       1.0
# 14               15.5                       3.0
# 15               14.1                       6.0
# 16                3.2                       5.0
# 17                4.1                       2.0
# 18                1.0                       4.0
# 19                NaN                       NaN
# 20                2.5                       4.0
# 21               10.7                       2.0
# 22                1.8                       1.0
# 23               10.1                       7.0
# 24               11.6                       5.0
# 25                7.8                       3.0
# 26                3.7                       6.0
# 27               20.5                       7.0
# 28                1.8                       3.0
# 29                5.1                       2.0
# ...               ...                       ...
# 7376              NaN                       NaN
# 7377              NaN                       NaN
# 7378              9.6                       5.0
# 7379             15.5                       3.0
# 7380              2.7                       6.0
# 7381              9.1                       1.0
# 7382              1.7                       2.0
# 7383              5.9                       7.0
# 7384              4.9                       4.0
# 7385              NaN                       NaN
# 7386              3.4                       4.0
# 7387             21.1                       3.0
# 7388              0.9                       2.0
# 7389              1.8                       1.0
# 7390             15.1                       5.0
# 7391              6.1                       5.0
# 7392             24.3                       8.0
# 7393              3.2                       4.0
# 7394              1.2                       1.0
# 7395             14.5                       7.0
# 7396             25.7                       3.0
# 7397              6.6                       2.0
# 7398              8.9                       6.0
# 7399              NaN                       NaN
# 7400              3.8                       2.0
# 7401              8.7                       3.0
# 7402              1.3                       1.0
# 7403              3.7                       4.0
# 7404              9.5                       5.0
# 7405              4.0                       6.0
#
# [7406 rows x 2 columns]

# %%
import numpy as np
for race_id, group in dfX_hist.groupby("race_id"):
    print(race_id)
    is_min = lambda x: x==x.min()
    group["is_favorate_odds"] = group["final_tote_odds"].transform(is_min)
#     print(group["official_finish_position"])
#     print(group["o"])
    break
# Out:
# ALB_20170705_1
# /Users/xiayuxuan/anaconda/envs/py35/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
dfX_hist['x8is_favorate_odds'] = dfX_hist.groupby('race_id')['final_tote_odds'].transform(lambda x: x==x.min())

# %%
dfX_hist['x8is_favorate_win'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]==1, axis=1)

# %%
dfX_hist['x8is_favorate_place'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]==2, axis=1)

# %%
dfX_hist['x8is_favorate_show'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]==3, axis=1)

# %%
dfX_hist['x8is_favorate_otb'] = dfX_hist.transform(lambda x: x["x8is_favorate_odds"]==True and x["official_finish_position"]>3, axis=1)

# %%
dfX_hist[]
